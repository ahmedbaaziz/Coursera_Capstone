# %% [markdown]
# # <b> Capstone Project - The Battle of Neighborhoods (Week 1-2) </b>
# <br>
# <br>
# <br>
# This notebook is part of a Capstone Project - The Battle of Neighborhoods, part of the IBM Data Science Professional Certificate. It contains the following sections:<br>
# <br>
#     (week-1)<br>
#     - Business Problem section: describes the problem and its background.<br>
#     - Data section: describes the data and how it will be used to solve the problem.<br>
# <br>
#     (week-2)<br>
#     - Methodology section: describes the exploratory data analysis we performed.<br>
#     - Result and discussion section: details the results of our analysis.<br>
#     - Conclusion section: summarizes our findings and highlights main conclusions.<br>
# <br>
# <br>

# %% [markdown]
# ### <b>Business Problem section </b><br>
# <b> Favourable locations for a new café in busy London.</b><br>
# <br>
# Experts agree that Britain now has one of the most vibrant coffee cultures in the world, which is showcased by the constant increase year after year of the number of the London Coffee Festival attendees - more than 31000 people attended last year edition (2019).<br>
# Knowing that UK residents consume 95 million cups of coffee per day and their love for the black elixir is growing, a new entrepreneur is looking at opening an independent café in London where he can connect with his customers and share his passion for the coffee culture. The main challenge is the strong competition - the number of cafés more than doubled in UK since 2010. In fact, London's West End is now home to more Starbucks' branches than the whole of Australia.<br>
# <br>
# Beside the menu and the ambiance, the location of a café is fundamental to its success. Many cafés are positioned in busy streets, but this is not the only criteria especially when we are considering a crowded city like London. Most people pick a coffee shop for its convenience - in the centre, close to offices or in an area knowing for good cafés. <br>
# <br>
# The entrepreneur is asking if we can help him identifying the best neighborhoods to open a new café, using a data-driven approach - which will be the topic of this project.<br>
# To solve this problem, we will identify London neighborhoods, check the numbers of cafés in each one of them. We will then recommend the best neighborhoods (most profitable) according to the overall cafés rating in these areas and how they are perceived by customers, taking in consideration the number of existent cafés.<br>
# <br>
# In a wider picture, this problem is targeting all entrepreneurs who are thinking of opening a new café in London, or even for just the café lovers to check the neighborhoods with the best coffee shops rating.
# <br>
# <br>
# <br>

# %% [markdown]
# ### <b>Data section</b><br>
# <br>
# The Data Science Workflow used for this project is:<br>
# <br>
#     - Outline the initial data that is required.<br>
#     - Obtain the data:<br>
#         ○ Find suitable sources for London neighborhoods<br>
#         ○ Explore the data<br>
#     - Initial data wrangling and cleaning.<br>
#     - Data analysis and Location data:<br>
#         ○ Foursquare location data will be leveraged to explore cafés in London neighborhoods.<br>
#         ○ Data manipulation and analysis.<br>
#     - Visualization of the data.<br>
# <br>
# <br>
# London city is actually divided in 38 boroughs. But in order to provide a good results for our entrepreneur, we decided to analyse the data of London neighborhoods. <br>
# Ideally, the data should include list of boroughs, neighborhoods, latitude and longitude for each neighborhood, list of cafés/coffee shops per neighborhood and the tips/recommendation per café. We also considered looking at the population per borough, which may help us in the end of the project to select the best locations for the new café.<br>
# <br>
# To find and get the needed data, we had to to search in different sources, then wrangle and clean it.<br>
# London boroughs and neighborhoods data is available in the Wikipedia page - https://en.wikipedia.org/wiki/List_of_areas_of_London, we then used the Geopy library in Python to get the latitude and longitude of each neighborhood.<br>
# London population per borough data is available in the website gov.uk, in a CSV file format (file name: "Population borough London").<br>
# Data related to available cafés and coffee shops, their locations and their details, will be obtained via the Foursquare API via the Request library in Python.<br>
# <br>

# %% [markdown]
# #### Install the required packages
# To be able to collect the data and analyze it, we will need to install the following packages:

# %%
# !conda install -c conda-forge --no-deps wikipedia --yes   # installing Wikipedia package 

# installing BeautifulSoup and lxml packages
# !conda install -c conda-forge --no-deps beautifulsoup4 --yes   
# !conda install -c conda-forge --no-deps lxml --yes  

# installing Geocoder and related packages
# !conda install -c conda-forge --no-deps geocoder --yes    
# !conda install -c conda-forge --no-deps ratelim --yes   
# !conda install -c conda-forge --no-deps click --yes   
# !conda install -c conda-forge --no-deps altair --yes    
# !conda install -c conda-forge --no-deps vincent --yes   

# !conda install -c conda-forge geopy=1.21.0 --yes   # installing Geopy package 

# !conda install -c conda-forge --no-deps folium=0.10.1 --yes   # installing Folium package 

# !conda install -c conda-forge --no-deps googlemaps --yes   # installing googlemaps package
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - wikipedia
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     wikipedia-1.4.0            |             py_2          13 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          13 KB
#
# The following NEW packages will be INSTALLED:
#
#   wikipedia          conda-forge/noarch::wikipedia-1.4.0-py_2
#
#
#
# Downloading and Extracting Packages
# wikipedia-1.4.0      | 13 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::wikipedia==1.4.0=py_2
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.9.0       |   py36h9f0ad1d_0         160 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         160 KB
#
# The following NEW packages will be INSTALLED:
#
#   beautifulsoup4     conda-forge/linux-64::beautifulsoup4-4.9.0-py36h9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# beautifulsoup4-4.9.0 | 160 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::wikipedia==1.4.0=py_2
#   - conda-forge/linux-64::beautifulsoup4==4.9.0=py36h9f0ad1d_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     lxml-3.8.0                 |           py36_0         3.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   lxml               conda-forge/linux-64::lxml-3.8.0-py36_0
#
#
#
# Downloading and Extracting Packages
# lxml-3.8.0           | 3.8 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::lxml==3.8.0=py36_0
#   - conda-forge/noarch::wikipedia==1.4.0=py_2
#   - conda-forge/linux-64::beautifulsoup4==4.9.0=py36h9f0ad1d_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geocoder
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geocoder-1.38.1            |             py_1          53 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          53 KB
#
# The following NEW packages will be INSTALLED:
#
#   geocoder           conda-forge/noarch::geocoder-1.38.1-py_1
#
#
#
# Downloading and Extracting Packages
# geocoder-1.38.1      | 53 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::lxml==3.8.0=py36_0
#   - conda-forge/noarch::wikipedia==1.4.0=py_2
#   - conda-forge/noarch::geocoder==1.38.1=py_1
#   - conda-forge/linux-64::beautifulsoup4==4.9.0=py36h9f0ad1d_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - ratelim
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ratelim-0.1.6              |             py_2           6 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:           6 KB
#
# The following NEW packages will be INSTALLED:
#
#   ratelim            conda-forge/noarch::ratelim-0.1.6-py_2
#
#
#
# Downloading and Extracting Packages
# ratelim-0.1.6        | 6 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::lxml==3.8.0=py36_0
#   - conda-forge/noarch::ratelim==0.1.6=py_2
#   - conda-forge/noarch::wikipedia==1.4.0=py_2
#   - conda-forge/noarch::geocoder==1.38.1=py_1
#   - conda-forge/linux-64::beautifulsoup4==4.9.0=py36h9f0ad1d_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - click
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     click-7.1.1                |     pyh8c360ce_0          64 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          64 KB
#
# The following NEW packages will be INSTALLED:
#
#   click              conda-forge/noarch::click-7.1.1-pyh8c360ce_0
#
#
#
# Downloading and Extracting Packages
# click-7.1.1          | 64 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
# \
#   - conda-forge/linux-64::lxml==3.8.0=py36_0
#   - conda-forge/noarch::ratelim==0.1.6=py_2
#   - conda-forge/noarch::wikipedia==1.4.0=py_2
#   - conda-forge/noarch::geocoder==1.38.1=py_1
#   - conda-forge/linux-64::beautifulsoup4==4.9.0=py36h9f0ad1d_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - altair
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         614 KB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#
#
#
# Downloading and Extracting Packages
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::lxml==3.8.0=py36_0
#   - conda-forge/noarch::ratelim==0.1.6=py_2
#   - conda-forge/noarch::wikipedia==1.4.0=py_2
#   - conda-forge/noarch::geocoder==1.38.1=py_1
#   - conda-forge/noarch::altair==4.1.0=py_1
#   - conda-forge/linux-64::beautifulsoup4==4.9.0=py36h9f0ad1d_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - vincent
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          28 KB
#
# The following NEW packages will be INSTALLED:
#
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::lxml==3.8.0=py36_0
#   - conda-forge/noarch::vincent==0.4.4=py_1
#   - conda-forge/noarch::ratelim==0.1.6=py_2
#   - conda-forge/noarch::wikipedia==1.4.0=py_2
#   - conda-forge/noarch::geocoder==1.38.1=py_1
#   - conda-forge/noarch::altair==4.1.0=py_1
#   - conda-forge/linux-64::beautifulsoup4==4.9.0=py36h9f0ad1d_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy=1.21.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.8           |   py36h45558ae_2         628 KB  conda-forge
#     future-0.18.2              |   py36h9f0ad1d_1         714 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     jinja2-2.11.2              |     pyh9f0ad1d_0          93 KB  conda-forge
#     libxslt-1.1.33             |       h7d1a2b0_0         426 KB
#     pandas-1.0.3               |   py36h830a2c2_0        11.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     soupsieve-1.9.4            |   py36h9f0ad1d_1          58 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     urllib3-1.25.8             |   py36h9f0ad1d_1         160 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.8-py36h45558ae_2
#   decorator          conda-forge/noarch::decorator-4.4.2-py_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   future             conda-forge/linux-64::future-0.18.2-py36h9f0ad1d_1
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib-metadata conda-forge/linux-64::importlib-metadata-1.6.0-py36h9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   libxslt            pkgs/main/linux-64::libxslt-1.1.33-h7d1a2b0_0
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.3-py36h830a2c2_0
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2019.3-py_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   soupsieve          conda-forge/linux-64::soupsieve-1.9.4-py36h9f0ad1d_1
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/linux-64::urllib3-1.25.8-py36h9f0ad1d_1
#   zipp               conda-forge/noarch::zipp-3.1.0-py_0
#
#
#
# Downloading and Extracting Packages
# soupsieve-1.9.4      | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# jinja2-2.11.2        | 93 KB     | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# cryptography-2.8     | 628 KB    | ##################################### | 100%
# libxslt-1.1.33       | 426 KB    | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# pandas-1.0.3         | 11.1 MB   | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# future-0.18.2        | 714 KB    | ##################################### | 100%
# urllib3-1.25.8       | 160 KB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.10.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.10.1              |             py_0          59 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          59 KB
#
# The following NEW packages will be INSTALLED:
#
#   folium             conda-forge/noarch::folium-0.10.1-py_0
#
#
#
# Downloading and Extracting Packages
# folium-0.10.1        | 59 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::folium==0.10.1=py_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - googlemaps
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     googlemaps-2.5.1           |             py_0          23 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          23 KB
#
# The following NEW packages will be INSTALLED:
#
#   googlemaps         conda-forge/noarch::googlemaps-2.5.1-py_0
#
#
#
# Downloading and Extracting Packages
# googlemaps-2.5.1     | 23 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# #### Get the data from Wikipedia
# As mentioned before, the first part of our data (London neighborhoods and boroughs) is available in the Wikipedia page "https://en.wikipedia.org/wiki/List_of_areas_of_London". <br>
# We start by importing the required libraries then use BeautifulSoup to get the data - this Python library generates duplicate lines in the resulted dataframe, so some cleaning and wrangling will be needed.

# %%
import requests
import pandas as pd
import random  # library for random number generation

from bs4 import BeautifulSoup
from pandas.io.json import json_normalize
from urllib.request import urlopen

url = 'https://en.wikipedia.org/wiki/List_of_areas_of_London'
parsed_table = []

def get_wikipedia_data(u):
    wiki_url = requests.get(u).text
    soup = BeautifulSoup(wiki_url, 'html5lib')
    rows = soup.find('table', class_='wikitable sortable').find_all('tr')
    
    for row in rows:
        children = row.findChildren(recursive=False)
        row_text = []
        for child in children:
            clean_text = child.text
            clean_text = clean_text.split('&#91;')[0]     # This is to discard reference/citation links
            clean_text = clean_text.split('&#160;')[-1]   # This is to clean the header row of the sort icons
            clean_text = clean_text.strip()
            row_text.append(clean_text)
            parsed_table.append(row_text)
   
    return parsed_table

if __name__=="__main__":
    print ('this is the data:')
    tor_list = get_wikipedia_data(url) 
    #for row in tor_df:
    #    print ('|'.join(row))

# Create our dataframe from the html text
london_neighborhood_df = pd.DataFrame (tor_list,columns=['Location', 'London borough', 'Post town', 'Postcode district', 'Dial code', 'OS grid ref'])

# To eliminate all duplicate rows
london_neighborhood_df = london_neighborhood_df.drop_duplicates()

# To drop first row in the dataframe, since it's listing the columns' names
london_neighborhood_df.drop(london_neighborhood_df.index[:1], inplace=True)

london_neighborhood_df.head(10)
# Out:
# this is the data:
#             Location                     London borough       Post town  \
# 6         Abbey Wood             Bexley,  Greenwich [7]          LONDON
# 12             Acton  Ealing, Hammersmith and Fulham[8]          LONDON
# 18         Addington                         Croydon[8]         CROYDON
# 24        Addiscombe                         Croydon[8]         CROYDON
# 30       Albany Park                             Bexley  BEXLEY, SIDCUP
# 36  Aldborough Hatch                       Redbridge[9]          ILFORD
# 42           Aldgate                           City[10]          LONDON
# 48           Aldwych                    Westminster[10]          LONDON
# 54          Alperton                          Brent[11]         WEMBLEY
# 60           Anerley                        Bromley[11]          LONDON
#
#    Postcode district Dial code OS grid ref
# 6                SE2       020    TQ465785
# 12            W3, W4       020    TQ205805
# 18               CR0       020    TQ375645
# 24               CR0       020    TQ345665
# 30         DA5, DA14       020    TQ478728
# 36               IG2       020    TQ455895
# 42               EC3       020    TQ334813
# 48               WC2       020    TQ307810
# 54               HA0       020    TQ185835
# 60              SE20       020    TQ345695

# %% [markdown]
# <br> We will then play with the data and clean the dataframe to get our final list of London neighborhoods and boroughs, where every neighborhood is unique and listed with its allocated borough.

# %%
# Cleaning our data

# Create a new dataframe with only the needed columns
london_df = london_neighborhood_df[['Location', 'London borough']].copy()

# Rename the columns
london_df.rename(columns = {'Location':'Neighborhood', 'London borough':'Borough'}, inplace = True) 

# Remove rows with a neighborhood that is "Not assigned".
london_df.drop(london_df[london_df['Neighborhood']=="Not assigned"].index,axis=0, inplace=True)

# If a Neighborhood is listed more than once, regroup all the boroughs in one row and seperate them with ','
london_df = london_df.groupby("Neighborhood").agg(lambda x:','.join(set(x)))

# If a neighborhood has more than one borough, only keep the first borough
london_df['Borough'] = london_df['Borough'].str.split(',').str[0]

# Some Boroughs have a number in the end (related to Wikipedia page), so we removed this
london_df['Borough'] = london_df['Borough'].str.split('[').str[0]

# We are replacing the borough "city" by "city of London"
london_df['Borough'] = london_df['Borough'].str.replace('City','City of London')

london_df.reset_index(level=0, inplace=True)

print(london_df.shape)
london_df.head(10)
# Out:
# (527, 2)
#        Neighborhood         Borough
# 0        Abbey Wood          Bexley
# 1             Acton          Ealing
# 2         Addington         Croydon
# 3        Addiscombe         Croydon
# 4       Albany Park          Bexley
# 5  Aldborough Hatch       Redbridge
# 6           Aldgate  City of London
# 7           Aldwych     Westminster
# 8          Alperton           Brent
# 9           Anerley         Bromley

# %%
# Let's check how many neighborhoods and boroughs we have

print('There are {} uniques Neighborhoods.'.format(len(london_df['Neighborhood'].unique())))
print('There are {} uniques Boroughs.'.format(len(london_df['Borough'].unique())))
# Out:
# There are 527 uniques Neighborhoods.
# There are 38 uniques Boroughs.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import seaborn as sns

london_df.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(10,5), color="blue")
plt.title('Neighborhoods per Borough: London', fontsize = 16)
plt.xlabel('Borough', fontsize = 12)
plt.ylabel('No. Neighborhoods',fontsize = 12)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# #### Get latitude and longitude coordinates
# Next step will be get the latitude and longitude for each neighborhood. For this, We will use the Python library Geopy.<br>
# This library is not always reliable and we faced some challenges using the code and getting the coordinates of all the neighborhoods. In some cases, the code returned a "service not available" error if we exceeded a certain number of requests in one time. As a workaround, you can split your data in multiple sections, and execute the code for each one of them. <br>
# After executing the code, some neighborhoods were missing their latitude and longitude coordinations. The number was very low (10) so we decided to just delete these rows.

# %%
from geopy.geocoders import Nominatim

london_df['Latitude'] = ""
london_df['Longitude'] = ""
geolocator = Nominatim(user_agent="capstone_project")

for index, row in london_df.iterrows():
    #if index<44:  ## this can be used to split your data
    site = row['Neighborhood']+", London, UK"
    location = geolocator.geocode(site)
    try:
        latitude = location.latitude
        longitude = location.longitude
    except:
        latitude = 'N/A'
        longitude = 'N/A'
    row['Latitude'] = latitude
    row['Longitude'] = longitude

# %%
# Remove rows with a latitude or longitude that is "N/A" or empty.
london_df.drop(london_df[london_df['Latitude']=="N/A"].index,axis=0, inplace=True)
london_df.drop(london_df[london_df['Latitude']==""].index,axis=0, inplace=True)
london_df.drop(london_df[london_df['Longitude']=="N/A"].index,axis=0, inplace=True)
london_df.drop(london_df[london_df['Longitude']==""].index,axis=0, inplace=True)

print(london_df.shape)
london_df.tail(20)
# Out:
# (517, 4)
#         Neighborhood                 Borough Latitude  Longitude
# 506   Westcombe Park               Greenwich  51.4842  0.0188787
# 507      Westminster             Westminster  51.5014   -0.12493
# 508        Whetstone                  Barnet  51.6302  -0.174884
# 509       White City  Hammersmith and Fulham  51.5119  -0.224236
# 510      Whitechapel           Tower Hamlets  51.5186 -0.0620807
# 511          Whitton    Richmond upon Thames  51.4512  -0.357976
# 513        Willesden                   Brent  51.5466  -0.235866
# 514        Wimbledon                  Merton  51.4215  -0.206403
# 515   Winchmore Hill                 Enfield  51.6334  -0.103362
# 516       Wood Green                Haringey   51.596  -0.109147
# 517         Woodford               Redbridge  51.6068  0.0340119
# 518   Woodford Green               Redbridge  51.6118  0.0240796
# 519        Woodlands                Hounslow  51.4722  -0.337432
# 520         Woodside                 Croydon  51.3871 -0.0653308
# 521    Woodside Park                  Barnet  51.6179  -0.185579
# 522         Woolwich               Greenwich  51.4827  0.0623335
# 523   Worcester Park                  Sutton  51.3784  -0.241602
# 524  Wormwood Scrubs  Hammersmith and Fulham  51.5214  -0.240439
# 525          Yeading              Hillingdon  51.5272   -0.39927
# 526         Yiewsley              Hillingdon  51.5129  -0.474152

# %% [markdown]
# <br><u>Remarque:</u>
# It's always a good practice to save your dataframe after using a Python library such as Geopy.

# %%
# Save the information so far to a .csv file 
london_df.to_csv('london_df.csv')
#london_df = pd.read_csv('london_df.csv')   ## use this commend to read the saved CSV file

# %% [markdown]
# #### Get the population per borough
# Based on the results we will end-up having, we will may need to know the population by borough to be able to select the best neighborhoods to open a café. This information is already available in the website www.gov.uk (https://data.london.gov.uk/dataset/land-area-and-population-density-ward-and-borough). <br>
# After understanding the data in the CSV file, we selected the needed columns and saved this as a second dataframe.

# %%
import csv

# !wget -q -O 'population_borough_london.csv' https://data.london.gov.uk/download/land-area-and-population-density-ward-and-borough/77e9257d-ad9d-47aa-aeed-59a00741f301/housing-density-borough.csv
lp_df = pd.read_csv('population_borough_london.csv')

# Select the year 2019
lp_df = lp_df[lp_df.Year == 2019]

# Create a new dataframe with only the needed columns
london_population_df = lp_df[['Name', 'Population']].copy()

# Rename the columns
london_population_df.rename(columns = {'Name':'Borough'}, inplace = True) 

# sorting the boroughs in a descending way and removing Greater, Outer and Inner london areas (not boroughs)
london_population_df.sort_values(by='Population', ascending=False, inplace=True)
london_population_df = london_population_df.iloc[3:]

print(london_population_df.shape)
london_population_df.head(36)
# Out:
# (33, 2)
#                      Borough  Population
# 124                   Barnet      402363
# 384                  Croydon      396548
# 1268                  Newham      359470
# 436                   Ealing      354184
# 228                    Brent      340710
# 488                  Enfield      339480
# 1112                 Lambeth      338028
# 280                  Bromley      334292
# 1632              Wandsworth      328828
# 1424               Southwark      327271
# 1528           Tower Hamlets      323696
# 1164                Lewisham      314027
# 852               Hillingdon      312567
# 1320               Redbridge      307690
# 540                Greenwich      289650
# 1580          Waltham Forest      286776
# 592                  Hackney      286425
# 696                 Haringey      285949
# 904                 Hounslow      281339
# 748                   Harrow      258861
# 800                 Havering      258655
# 1684             Westminster      258511
# 332                   Camden      255526
# 176                   Bexley      252885
# 956                Islington      241589
# 72      Barking and Dagenham      214858
# 1216                  Merton      210452
# 1476                  Sutton      209666
# 1372    Richmond upon Thames      200703
# 644   Hammersmith and Fulham      186075
# 1060    Kingston upon Thames      180598
# 1008  Kensington and Chelsea      160531
# 20            City of London        7953

# %% [markdown]
# <br>
# We now have important the relevant data for London neighborhoods and boroughs, and have constructed our dataframe. <br>
# Nest phase, we will use the Foursquare API to get info on cafés in each neighborhood  <br><br><br>

# %% [markdown]
# ### <b>Methodology section</b><br>
# <br>
# As stated above, we will now use the Foursquare API to get details about our neighborhoods and extra info on available cafés, which will help us to identify busy areas and understand customers behavior.<br>
# <br>
# To be able to use the Foursquare API, you'll need to have a developer profile and use your Foursquare credentials (client ID and client secret) - please see below. <br>
# Additionally, we will need to specify the version of the date (the date), the limit and the radius, which are needed for our requests.
# <br>

# %%
# Define details for Foursquare requests

CLIENT_ID = 'IWKKM4IYZLOOAHTBBCDWQHYRDGAOVAHRX1G20BPEFARUHJA0' # your Foursquare ID
CLIENT_SECRET = 'XZOV4W1BA5R1RKCD4SKMGXOXA54A3PNXESUB0XNL5B444Q4Y' # your Foursquare Secret
VERSION = '20200101' # Foursquare API version
radius = 350
limit = 80

# %% [markdown]
# <br>Let's use the functions defined in previous labs, which will allow us to get the nearby venues per neighborhood and the details for each neighborhood.<br>
# You should be aware of the limited number of request that you can execute per day (this will depends on your Foursquare profile and subscription), so it's important that you save your dataframe in a CSV file after you execute your request. <br>

# %%
# Functions to be used

def getNearbyVenues(names, latitudes, longitudes):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['id'], 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude',
                  'ID',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues) 

def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
#    print(results['response'].keys())
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
# Get the nearby venues for each neighborhood

venues = getNearbyVenues(names=london_df['Neighborhood'],
                         latitudes=london_df['Latitude'],
                         longitudes=london_df['Longitude'])

venues.head()

# %%
# check how many unique categories can be curated from all the returned venues
print('There are {} uniques categories.'.format(len(venues['Venue Category'].unique())))

# check how many venues returned by neighborhood and classify then in descendant way
venues.groupby('Neighborhood').count().sort_values(['Venue'], ascending=False)
# Out:
# There are 375 uniques categories.
#                  Unnamed: 0  Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
# Wimbledon                80                     80                      80
# Brompton                 80                     80                      80
# Covent Garden            80                     80                      80
# Chinatown                80                     80                      80
# Richmond                 80                     80                      80
# ...                     ...                    ...                     ...
# Hazelwood                 1                      1                       1
# Shooter's Hill            1                      1                       1
# Cowley                    1                      1                       1
# Hackney Marshes           1                      1                       1
# Colyers                   1                      1                       1
#
#                  ID  Venue  Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Wimbledon        80     80              80               80              80
# Brompton         80     80              80               80              80
# Covent Garden    80     80              80               80              80
# Chinatown        80     80              80               80              80
# Richmond         80     80              80               80              80
# ...              ..    ...             ...              ...             ...
# Hazelwood         1      1               1                1               1
# Shooter's Hill    1      1               1                1               1
# Cowley            1      1               1                1               1
# Hackney Marshes   1      1               1                1               1
# Colyers           1      1               1                1               1
#
# [500 rows x 8 columns]

# %%
# Save the information so far to a .csv file due to limited calls on FourSquare
venues.to_csv('cafe_venues_london.csv')
#venues = pd.read_csv('cafe_venues_london.csv')
venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   Abbey Wood              51.487621                0.114050
# 1   Abbey Wood              51.487621                0.114050
# 2        Acton              51.508140               -0.273261
# 3        Acton              51.508140               -0.273261
# 4        Acton              51.508140               -0.273261
#
#                          ID                                 Venue  \
# 0  4bf181d61f17ef3bfcf59bc8                            Co-op Food
# 1  4bd315449854d13af6cffc4d                        Bostal Gardens
# 2  5658b22838fae7c08d97dc51                     London Star Hotel
# 3  4bc1c0b7920eb7130d191b2c  Dragonfly Brewery at George & Dragon
# 4  527c07e711d255a8e45a3856                          The Aeronaut
#
#    Venue Latitude  Venue Longitude Venue Category
# 0       51.487650         0.113490  Grocery Store
# 1       51.486670         0.110462     Playground
# 2       51.509624        -0.272456          Hotel
# 3       51.507378        -0.271702        Brewery
# 4       51.508376        -0.275216            Pub

# %% [markdown]
# <br>
# The generated results present info about all the venues in our neighborhoods. By checking all the types of categories returned by our Foursquare request, we are interested in "café" and "coffee shop" categories for this project. All other food places serving cafés will not be considered as direct competitors, and then can be ignored in our analysis. <br><br>
# Let's check how many cafés we have in our dataframe and see how they are distributed (per borough). <br><br>

# %%
# Let's see what's the name of venue used to refer to a café
venues['Venue Category'].unique()
# Out:
# array(['Grocery Store', 'Playground', 'Hotel', 'Brewery', 'Pub',
#        'Creperie', 'Fast Food Restaurant', 'Gym / Fitness Center',
#        'Sandwich Place', 'Coffee Shop', 'Chinese Restaurant',
#        'Cocktail Bar', 'Café', 'Shopping Mall', 'Japanese Restaurant',
#        'Gas Station', 'English Restaurant', 'Bus Station', 'Tram Station',
#        'Bakery', 'Diner', 'Park', 'Train Station', 'Indian Restaurant',
#        'Pizza Place', 'Argentinian Restaurant', 'Italian Restaurant',
#        'Lounge', 'Vietnamese Restaurant', 'Beer Bar', 'Mini Golf',
#        'Salad Place', 'Steakhouse', 'Szechuan Restaurant',
#        'Street Food Gathering', 'Thai Restaurant', 'Restaurant',
#        'Middle Eastern Restaurant', 'American Restaurant',
#        'Seafood Restaurant', 'Hotel Bar', 'Sushi Restaurant',
#        'Greek Restaurant', 'Gym', 'Bar', 'Spanish Restaurant',
#        'Art Gallery', 'French Restaurant', 'Tea Room', 'Historic Site',
#        'History Museum', 'Art Museum', 'Theater', 'Event Space',
#        'Building', 'Garden', 'Bookstore', 'Boat or Ferry', 'Wine Bar',
#        'Mexican Restaurant', 'Supermarket', 'Bus Stop',
#        'Paper / Office Supplies Store', 'Korean Restaurant', 'Food Truck',
#        'Turkish Restaurant', 'Wine Shop', 'Burrito Place', 'Cupcake Shop',
#        'Vegetarian / Vegan Restaurant', 'Nightclub', 'Fish Market',
#        'Arts & Crafts Store', 'Farmers Market', 'Clothing Store',
#        'Stationery Store', 'Boutique', 'Ramen Restaurant', 'Dance Studio',
#        'Frozen Yogurt Shop', 'Burger Joint', 'Yoga Studio', 'Pharmacy',
#        'Gastropub', 'Indonesian Restaurant', 'Asian Restaurant',
#        'Tapas Restaurant', 'Forest', 'Kebab Restaurant',
#        'Bike Rental / Bike Share', 'Flower Shop', 'Bay', 'Golf Course',
#        'Beer Store', 'Shop & Service', 'Moroccan Restaurant',
#        'Portuguese Restaurant', 'Organic Grocery', 'Breakfast Spot',
#        'Metro Station', 'Electronics Store', 'Warehouse Store',
#        'Dessert Shop', 'Home Service', 'Modern European Restaurant',
#        'Church', 'Museum', 'Performing Arts Venue', 'Bagel Shop', 'Plaza',
#        'Scenic Lookout', 'Discount Store', 'Platform', 'Soccer Field',
#        'Track', 'Sporting Goods Shop', 'Caucasian Restaurant',
#        'Ethiopian Restaurant', 'Garden Center', 'Deli / Bodega',
#        'Pet Store', 'Harbor / Marina', 'Ice Cream Shop',
#        'Brazilian Restaurant', 'Dim Sum Restaurant', 'Mobile Phone Shop',
#        'Noodle House', 'Hostel', 'Skating Rink', 'Cycle Studio', 'Market',
#        'Malay Restaurant', 'African Restaurant', 'Casino',
#        'Mediterranean Restaurant', 'Fish & Chips Shop', 'Movie Theater',
#        'Shopping Plaza', 'Furniture / Home Store', 'Light Rail Station',
#        'Convenience Store', 'Lake', 'Sports Club', 'Comedy Club',
#        'Cultural Center', 'Chocolate Shop', 'Lebanese Restaurant',
#        'Shoe Store', 'Lingerie Store', 'Cosmetics Shop', 'Hill',
#        'Nature Preserve', 'Eastern European Restaurant', 'Go Kart Track',
#        'Fried Chicken Joint', 'Arepa Restaurant', 'Gay Bar',
#        'Cricket Ground', 'South American Restaurant',
#        'Falafel Restaurant', 'Distillery', 'Juice Bar',
#        'Pedestrian Plaza', 'Himalayan Restaurant', 'Concert Hall',
#        'Irish Pub', 'Baby Store', 'Spa', 'Outdoor Sculpture',
#        'IT Services', 'Wings Joint', 'Used Bookstore', 'Exhibit',
#        'Health Food Store', 'Bistro', 'Bubble Tea Shop', 'Bowling Alley',
#        'New American Restaurant', 'Food', 'Gourmet Shop', 'Tennis Court',
#        'Department Store', 'Print Shop', 'Social Club', 'Music Venue',
#        'Donut Shop', 'Indie Movie Theater',
#        'Residential Building (Apartment / Condo)', 'Doner Restaurant',
#        'Nail Salon', 'Xinjiang Restaurant', 'Bike Shop', 'Pool Hall',
#        'Canal', 'Martial Arts Dojo', 'Veneto Restaurant',
#        'Caribbean Restaurant', 'Trail', 'Multiplex', 'Dry Cleaner',
#        'Athletics & Sports', 'Skate Park', 'Food & Drink Shop',
#        'Hardware Store', 'Peruvian Restaurant', 'Business Service',
#        'Gymnastics Gym', 'Speakeasy', 'Optical Shop',
#        'Belgian Restaurant', 'North Indian Restaurant', 'Fountain',
#        'Currywurst Joint', 'Monument / Landmark', 'Opera House',
#        'Construction & Landscaping', 'Salon / Barbershop',
#        "Women's Store", 'Health & Beauty Service',
#        'Japanese Curry Restaurant', 'Toy / Game Store',
#        'General Entertainment', 'Liquor Store', 'Jazz Club',
#        'Israeli Restaurant', 'Sri Lankan Restaurant', 'Candy Store',
#        'Udon Restaurant', 'Sake Bar', 'Comic Shop', 'Event Service',
#        'Persian Restaurant', 'Gift Shop', 'Thrift / Vintage Store',
#        'Hookah Bar', 'BBQ Joint', 'Sports Bar', 'Design Studio',
#        'Indoor Play Area', 'Brasserie', 'Flea Market', 'Food Court',
#        'Cheese Shop', 'Pakistani Restaurant', 'Track Stadium',
#        'Afghan Restaurant', 'Record Shop', 'Bank', 'Recording Studio',
#        'Gaming Cafe', 'Sculpture Garden', 'Farm', 'Beach',
#        'Housing Development', 'Stables', 'Souvenir Shop', 'Poke Place',
#        'Arts & Entertainment', 'Auto Workshop',
#        'Southern / Soul Food Restaurant', 'Video Game Store',
#        'Polish Restaurant', 'Road', 'Gym Pool', 'Soccer Stadium',
#        'Beer Garden', 'College Cafeteria', 'Cantonese Restaurant',
#        'Latin American Restaurant', 'College Rec Center', 'Rugby Pitch',
#        'Whisky Bar', 'Memorial Site', 'Souvlaki Shop',
#        'Scandinavian Restaurant', 'Radio Station', 'Soup Place',
#        'Film Studio', "Men's Store", 'Street Art', 'Moving Target',
#        'Rental Car Location', 'Vape Store', 'Outdoors & Recreation',
#        'Intersection', 'Dog Run', 'Shabu-Shabu Restaurant',
#        'Kosher Restaurant', 'Pool', 'Pie Shop',
#        'Tourist Information Center', 'Tunnel', 'Climbing Gym',
#        'Canal Lock', 'Photography Studio', 'Dive Bar', 'Rafting',
#        'Bed & Breakfast', 'Kids Store', 'Butcher', 'Auto Garage',
#        'Office', 'Arcade', 'Motorcycle Shop', 'Convention Center',
#        'Hobby Shop', 'Camera Store', 'Rock Club', 'Coffee Roaster',
#        'Laundromat', 'Outlet Store', 'Indie Theater', 'Buffet',
#        'Molecular Gastronomy Restaurant', 'Snack Place',
#        'Filipino Restaurant', 'Outdoor Supply Store', 'Botanical Garden',
#        'Tree', 'Fruit & Vegetable Store', 'Herbs & Spices Store',
#        'Cajun / Creole Restaurant', 'German Restaurant', 'Smoothie Shop',
#        'Kitchen Supply Store', 'Perfume Shop', 'Russian Restaurant',
#        'Jewelry Store', 'Piercing Parlor', 'Aquarium', 'Champagne Bar',
#        'Pilates Studio', 'Roof Deck', "Dentist's Office",
#        'Dumpling Restaurant', 'Volleyball Court', 'Reservoir',
#        'Leather Goods Store', 'Pastry Shop', 'South Indian Restaurant',
#        'Pier', 'Cafeteria', 'Neighborhood', 'Bowling Green',
#        'College Gym', 'Antique Shop', 'Australian Restaurant',
#        'Hockey Field', 'Community Center', 'Astrologer',
#        'Accessories Store', 'Music Store', 'Coworking Space',
#        'Other Repair Shop', 'Circus School', 'River', 'Veterinarian',
#        'Okonomiyaki Restaurant', 'Library', 'Post Office', 'Locksmith',
#        'Rock Climbing Spot', 'Massage Studio', 'Castle',
#        'Halal Restaurant', 'Waterfront', 'Food Service', 'Gun Shop',
#        'Knitting Store', 'Czech Restaurant', 'Chaat Place',
#        'Costume Shop', 'Recreation Center', 'Food Stand', 'Sausage Shop'],
#       dtype=object)

# %%
# check the neighborhoods with cafés
words=['Café', 'Coffee Shop']
london_cafe_df = venues[venues['Venue Category'].str.contains('|'.join(words))] 

# check if some venues are double listed and remove them
london_cafe_df = london_cafe_df.drop_duplicates(subset=['Venue','Venue Latitude','Venue Longitude'], keep='first')

print(london_cafe_df.shape)
london_cafe_df.head(20)
# Out:
# (925, 8)
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 11         Acton              51.508140               -0.273261
# 17         Acton              51.508140               -0.273261
# 24    Addiscombe              51.379692               -0.074282
# 44       Aldgate              51.514248               -0.075719
# 49       Aldgate              51.514248               -0.075719
# 59       Aldgate              51.514248               -0.075719
# 68       Aldgate              51.514248               -0.075719
# 73       Aldgate              51.514248               -0.075719
# 78       Aldgate              51.514248               -0.075719
# 79       Aldgate              51.514248               -0.075719
# 84       Aldgate              51.514248               -0.075719
# 92       Aldgate              51.514248               -0.075719
# 93       Aldgate              51.514248               -0.075719
# 113      Aldwych              51.513103               -0.114920
# 115      Aldwych              51.513103               -0.114920
# 154      Aldwych              51.513103               -0.114920
# 165      Aldwych              51.513103               -0.114920
# 174     Alperton              51.540804               -0.300096
# 181        Angel              51.531946               -0.106106
# 190        Angel              51.531946               -0.106106
#
#                            ID                            Venue  \
# 11   517d323fe4b0b4d24c007345                     Costa Coffee
# 17   4d971048a2c654815e9dce53                     Frank's Cafe
# 24   533fea17498e1f39b6eab646                    The Tram Stop
# 44   4f70a772e4b0f375fc669005                  The Association
# 49   4cb1d779562d224b09ec2188                          Fazenda
# 59   59f97d45acb00b6e13f7d430               Black Sheep Coffee
# 68   58af36849435a903b9148728                Whitechapel Grind
# 73   56bd9566498e17276fd1943c                    Nude Espresso
# 78   5548bf3e498e5a453a75bb45               Black Sheep Coffee
# 79   56cf0e4c498e3a5a5e7326c3  Notes Coffee Roaster & Wine Bar
# 84   520e158a11d25f11387631f8                     Peter's Cafe
# 92   4dbfe04693a0b5a1561e7785                     Costa Coffee
# 93   4b03dbaef964a5205f5022e3                        Starbucks
# 113  55c34aac498e536d77bc73b0                        Lundenwic
# 115  4d78eb92b706224b8450308d           The Fleet Street Press
# 154  586b9d4e4988da05edce66c1                      Soho Coffee
# 165  4b914a36f964a52060b033e3                      LSE Garrick
# 174  52f34f55498e0ac5d6fa8505            Alperton Sandwich Bar
# 181  54293665498e82f0e3cc82ea                   Saint Espressō
# 190  4fc9ff8ce4b087d229f75ce4          The Coffeeworks Project
#
#      Venue Latitude  Venue Longitude Venue Category
# 11        51.506879        -0.269368    Coffee Shop
# 17        51.508083        -0.270300           Café
# 24        51.380188        -0.073378           Café
# 44        51.513733        -0.079132    Coffee Shop
# 49        51.516169        -0.077414    Coffee Shop
# 59        51.513990        -0.075459    Coffee Shop
# 68        51.514409        -0.072834    Coffee Shop
# 73        51.516894        -0.075482    Coffee Shop
# 78        51.515066        -0.072126    Coffee Shop
# 79        51.514643        -0.080671    Coffee Shop
# 84        51.514076        -0.075482           Café
# 92        51.514966        -0.072658    Coffee Shop
# 93        51.511556        -0.075125    Coffee Shop
# 113       51.512823        -0.118343    Coffee Shop
# 115       51.513710        -0.111678    Coffee Shop
# 154       51.513333        -0.113325    Coffee Shop
# 165       51.513405        -0.116588           Café
# 174       51.541683        -0.297449           Café
# 181       51.531919        -0.107565    Coffee Shop
# 190       51.534254        -0.104684    Coffee Shop

# %%
# add the borough to the datafram
borough_df = london_df[["Neighborhood", "Borough"]].copy()
london_cafe_df = london_cafe_df.merge(borough_df, on='Neighborhood', how='left')

# move column Borough to the first column
fixed_columns = [london_cafe_df.columns[-1]] + list(london_cafe_df.columns[:-1])
london_cafe_df = london_cafe_df[fixed_columns]

print(london_cafe_df.shape)
london_cafe_df.head(10)
# Out:
# (925, 9)
#           Borough Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0          Ealing        Acton              51.508140               -0.273261
# 1          Ealing        Acton              51.508140               -0.273261
# 2         Croydon   Addiscombe              51.379692               -0.074282
# 3  City of London      Aldgate              51.514248               -0.075719
# 4  City of London      Aldgate              51.514248               -0.075719
# 5  City of London      Aldgate              51.514248               -0.075719
# 6  City of London      Aldgate              51.514248               -0.075719
# 7  City of London      Aldgate              51.514248               -0.075719
# 8  City of London      Aldgate              51.514248               -0.075719
# 9  City of London      Aldgate              51.514248               -0.075719
#
#                          ID                            Venue  Venue Latitude  \
# 0  517d323fe4b0b4d24c007345                     Costa Coffee       51.506879
# 1  4d971048a2c654815e9dce53                     Frank's Cafe       51.508083
# 2  533fea17498e1f39b6eab646                    The Tram Stop       51.380188
# 3  4f70a772e4b0f375fc669005                  The Association       51.513733
# 4  4cb1d779562d224b09ec2188                          Fazenda       51.516169
# 5  59f97d45acb00b6e13f7d430               Black Sheep Coffee       51.513990
# 6  58af36849435a903b9148728                Whitechapel Grind       51.514409
# 7  56bd9566498e17276fd1943c                    Nude Espresso       51.516894
# 8  5548bf3e498e5a453a75bb45               Black Sheep Coffee       51.515066
# 9  56cf0e4c498e3a5a5e7326c3  Notes Coffee Roaster & Wine Bar       51.514643
#
#    Venue Longitude Venue Category
# 0        -0.269368    Coffee Shop
# 1        -0.270300           Café
# 2        -0.073378           Café
# 3        -0.079132    Coffee Shop
# 4        -0.077414    Coffee Shop
# 5        -0.075459    Coffee Shop
# 6        -0.072834    Coffee Shop
# 7        -0.075482    Coffee Shop
# 8        -0.072126    Coffee Shop
# 9        -0.080671    Coffee Shop

# %%
# check how many cafés per borough

london_cafe_df.groupby('Borough')['Venue'].count().plot.bar(figsize=(20,5), color="blue")
plt.title('Cafés per borough: London', fontsize = 16)
plt.xlabel('Borough', fontsize = 12)
plt.ylabel('No. cafés',fontsize = 12)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# <br>
# In this project we will direct our efforts on detecting neighborhoods in London that have a reasonable cafés density and that are known with a great coffee culture. <br><br>
# Looking at the previous graph, we can see that some boroughs (not even neighborhoods) have a very small number of cafés. We can say that the competition is non-existent in these areas, but since our market is London and we already highlighted the fact that the coffee culture has been booming in the last 10-15 years, these boroughs are not known for good cafés and should not be considered as a good location to open a new café.
# <br><br>
#
# Let's progress with further analysis - for our next step, we will try to identify where customers like to go for a cafés, identify most liked neighborhoods and see which ones may be suitable for our entrepreneur. <br>
# We will use the Foursquare API to get the details of each café in our list. We are mainly interested in the "likes", the "tips" and the "rating". <br><br>

# %%
column=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips', 'Venue', 'Venue Latitude', 'Venue Longitude']
cafe_stats_london=pd.DataFrame(columns=column)
count=1

for row in london_cafe_df.values.tolist():
    Borough, Neighborhood, Neighborhood_Latitude, Neighborhood_Longitude, ID, Venue, Venue_Latitude, Venue_Longitude, Venue_Category=row
    try:
        venue_details = get_venue_details(ID)
        id,name,likes,rating,tips = venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these cafés as they may have been recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(london_cafe_df),')','processed')
    cafe_stats_london = cafe_stats_london.append({'Borough': Borough,
                                            'Neighborhood': Neighborhood, 
                                            'ID': id,
                                            'Venue' : name,
                                            'Likes' : likes,
                                            'Rating' : rating,
                                            'Tips' : tips,
                                            'Venue Latitude' : Venue_Latitude,
                                            'Venue Longitude' : Venue_Longitude
                                                }, ignore_index=True)
    count+=1

print(cafe_stats_london.shape)
cafe_stats_london.head(20)
# Out:
# ( 1 / 425 ) processed
# ( 2 / 425 ) processed
# ( 3 / 425 ) processed
# ( 4 / 425 ) processed
# ( 5 / 425 ) processed
# ( 6 / 425 ) processed
# ( 7 / 425 ) processed
# ( 8 / 425 ) processed
# ( 9 / 425 ) processed
# ( 10 / 425 ) processed
# ( 11 / 425 ) processed
# ( 12 / 425 ) processed
# ( 13 / 425 ) processed
# No data available for id= 5217d90611d2eda63cd99981
# ( 14 / 425 ) processed
# ( 15 / 425 ) processed
# ( 16 / 425 ) processed
# ( 17 / 425 ) processed
# ( 18 / 425 ) processed
# ( 19 / 425 ) processed
# ( 20 / 425 ) processed
# ( 21 / 425 ) processed
# ( 22 / 425 ) processed
# ( 23 / 425 ) processed
# ( 24 / 425 ) processed
# ( 25 / 425 ) processed
# ( 26 / 425 ) processed
# No data available for id= 4f8d6437e4b013d9a5231f1c
# ( 27 / 425 ) processed
# No data available for id= 4b49cd87f964a520d97326e3
# ( 28 / 425 ) processed
# No data available for id= 4e01ea57d22db37fb0298ae6
# ( 29 / 425 ) processed
# ( 30 / 425 ) processed
# ( 31 / 425 ) processed
# ( 32 / 425 ) processed
# ( 33 / 425 ) processed
# ( 34 / 425 ) processed
# No data available for id= 5a881b4f9d6a1952f5e4ca35
# ( 35 / 425 ) processed
# ( 36 / 425 ) processed
# ( 37 / 425 ) processed
# No data available for id= 4c8a4e3752a98cfa323e2be9
# ( 38 / 425 ) processed
# ( 39 / 425 ) processed
# ( 40 / 425 ) processed
# ( 41 / 425 ) processed
# ( 42 / 425 ) processed
# ( 43 / 425 ) processed
# ( 44 / 425 ) processed
# No data available for id= 52762947498e3d839086e0c3
# ( 45 / 425 ) processed
# ( 46 / 425 ) processed
# ( 47 / 425 ) processed
# ( 48 / 425 ) processed
# ( 49 / 425 ) processed
# ( 50 / 425 ) processed
# No data available for id= 4c8b531a52a98cfa51f734e9
# ( 51 / 425 ) processed
# ( 52 / 425 ) processed
# ( 53 / 425 ) processed
# ( 54 / 425 ) processed
# ( 55 / 425 ) processed
# ( 56 / 425 ) processed
# ( 57 / 425 ) processed
# No data available for id= 54cf5199498e4ef40de6ddcd
# ( 58 / 425 ) processed
# ( 59 / 425 ) processed
# ( 60 / 425 ) processed
# ( 61 / 425 ) processed
# ( 62 / 425 ) processed
# ( 63 / 425 ) processed
# ( 64 / 425 ) processed
# ( 65 / 425 ) processed
# ( 66 / 425 ) processed
# No data available for id= 4b264571f964a520b37924e3
# ( 67 / 425 ) processed
# ( 68 / 425 ) processed
# ( 69 / 425 ) processed
# No data available for id= 4bbd7a214e069c7477d89ee3
# ( 70 / 425 ) processed
# No data available for id= 4bc18f5a4cdfc9b60bdd9421
# ( 71 / 425 ) processed
# ( 72 / 425 ) processed
# ( 73 / 425 ) processed
# ( 74 / 425 ) processed
# ( 75 / 425 ) processed
# ( 76 / 425 ) processed
# ( 77 / 425 ) processed
# ( 78 / 425 ) processed
# ( 79 / 425 ) processed
# ( 80 / 425 ) processed
# ( 81 / 425 ) processed
# ( 82 / 425 ) processed
# ( 83 / 425 ) processed
# ( 84 / 425 ) processed
# ( 85 / 425 ) processed
# ( 86 / 425 ) processed
# ( 87 / 425 ) processed
# ( 88 / 425 ) processed
# ( 89 / 425 ) processed
# ( 90 / 425 ) processed
# ( 91 / 425 ) processed
# ( 92 / 425 ) processed
# No data available for id= 4e48f5ec1f6e29f10dc5f9f4
# ( 93 / 425 ) processed
# ( 94 / 425 ) processed
# ( 95 / 425 ) processed
# No data available for id= 4f72c35ce4b0a4b289d50a26
# ( 96 / 425 ) processed
# ( 97 / 425 ) processed
# No data available for id= 55852e3d498e29ca0a7f7995
# ( 98 / 425 ) processed
# No data available for id= 4bd6e6e66798ef3bcdc8658d
# ( 99 / 425 ) processed
# ( 100 / 425 ) processed
# ( 101 / 425 ) processed
# ( 102 / 425 ) processed
# ( 103 / 425 ) processed
# ( 104 / 425 ) processed
# ( 105 / 425 ) processed
# No data available for id= 4e281b5a8877f9158a7132d4
# ( 106 / 425 ) processed
# No data available for id= 539ed8ad498ef1b1c9d7788a
# ( 107 / 425 ) processed
# ( 108 / 425 ) processed
# ( 109 / 425 ) processed
# No data available for id= 4d6558796d9437049a2b76bf
# ( 110 / 425 ) processed
# ( 111 / 425 ) processed
# ( 112 / 425 ) processed
# ( 113 / 425 ) processed
# ( 114 / 425 ) processed
# ( 115 / 425 ) processed
# No data available for id= 4d00d28e6923721eefa6c63b
# ( 116 / 425 ) processed
# ( 117 / 425 ) processed
# ( 118 / 425 ) processed
# No data available for id= 4ea6b0519adf05b8d0597fa5
# ( 119 / 425 ) processed
# No data available for id= 4ec5109d77c8d69511100d0a
# ( 120 / 425 ) processed
# No data available for id= 4c2f0a2d66e40f47f23ec18b
# ( 121 / 425 ) processed
# ( 122 / 425 ) processed
# ( 123 / 425 ) processed
# ( 124 / 425 ) processed
# No data available for id= 4d3edc1414aa8cfad08cc15e
# ( 125 / 425 ) processed
# No data available for id= 4f990c58e4b0973bbc2cb54b
# ( 126 / 425 ) processed
# ( 127 / 425 ) processed
# ( 128 / 425 ) processed
# ( 129 / 425 ) processed
# ( 130 / 425 ) processed
# ( 131 / 425 ) processed
# ( 132 / 425 ) processed
# ( 133 / 425 ) processed
# ( 134 / 425 ) processed
# ( 135 / 425 ) processed
# ( 136 / 425 ) processed
# ( 137 / 425 ) processed
# ( 138 / 425 ) processed
# ( 139 / 425 ) processed
# ( 140 / 425 ) processed
# ( 141 / 425 ) processed
# ( 142 / 425 ) processed
# ( 143 / 425 ) processed
# ( 144 / 425 ) processed
# ( 145 / 425 ) processed
# ( 146 / 425 ) processed
# ( 147 / 425 ) processed
# ( 148 / 425 ) processed
# ( 149 / 425 ) processed
# ( 150 / 425 ) processed
# ( 151 / 425 ) processed
# ( 152 / 425 ) processed
# ( 153 / 425 ) processed
# ( 154 / 425 ) processed
# No data available for id= 573cc32e498e3a2e59571f5b
# ( 155 / 425 ) processed
# ( 156 / 425 ) processed
# ( 157 / 425 ) processed
# ( 158 / 425 ) processed
# ( 159 / 425 ) processed
# ( 160 / 425 ) processed
# ( 161 / 425 ) processed
# ( 162 / 425 ) processed
# ( 163 / 425 ) processed
# ( 164 / 425 ) processed
# ( 165 / 425 ) processed
# ( 166 / 425 ) processed
# ( 167 / 425 ) processed
# ( 168 / 425 ) processed
# ( 169 / 425 ) processed
# ( 170 / 425 ) processed
# ( 171 / 425 ) processed
# ( 172 / 425 ) processed
# ( 173 / 425 ) processed
# No data available for id= 4b879c18f964a5204fc431e3
# ( 174 / 425 ) processed
# ( 175 / 425 ) processed
# ( 176 / 425 ) processed
# ( 177 / 425 ) processed
# ( 178 / 425 ) processed
# ( 179 / 425 ) processed
# ( 180 / 425 ) processed
# ( 181 / 425 ) processed
# ( 182 / 425 ) processed
# ( 183 / 425 ) processed
# No data available for id= 4e996972f5b9a9af67b6a5c0
# ( 184 / 425 ) processed
# ( 185 / 425 ) processed
# ( 186 / 425 ) processed
# ( 187 / 425 ) processed
# ( 188 / 425 ) processed
# ( 189 / 425 ) processed
# ( 190 / 425 ) processed
# ( 191 / 425 ) processed
# No data available for id= 4f9035f9e4b0d6c8aaa956ff
# ( 192 / 425 ) processed
# No data available for id= 4c7b83caa86837044b83164d
# ( 193 / 425 ) processed
# No data available for id= 4aed6944f964a52096cd21e3
# ( 194 / 425 ) processed
# ( 195 / 425 ) processed
# ( 196 / 425 ) processed
# ( 197 / 425 ) processed
# ( 198 / 425 ) processed
# ( 199 / 425 ) processed
# ( 200 / 425 ) processed
# ( 201 / 425 ) processed
# No data available for id= 4e2e9938a8092ca5c37692ae
# ( 202 / 425 ) processed
# No data available for id= 51d938bd498edc776fdc4a2f
# ( 203 / 425 ) processed
# ( 204 / 425 ) processed
# ( 205 / 425 ) processed
# No data available for id= 5b24d80b364d970039ae88f8
# ( 206 / 425 ) processed
# ( 207 / 425 ) processed
# ( 208 / 425 ) processed
# ( 209 / 425 ) processed
# ( 210 / 425 ) processed
# ( 211 / 425 ) processed
# ( 212 / 425 ) processed
# ( 213 / 425 ) processed
# ( 214 / 425 ) processed
# ( 215 / 425 ) processed
# ( 216 / 425 ) processed
# ( 217 / 425 ) processed
# ( 218 / 425 ) processed
# ( 219 / 425 ) processed
# ( 220 / 425 ) processed
# ( 221 / 425 ) processed
# ( 222 / 425 ) processed
# ( 223 / 425 ) processed
# ( 224 / 425 ) processed
# ( 225 / 425 ) processed
# ( 226 / 425 ) processed
# No data available for id= 4e03009d483bb38cf0f1774d
# ( 227 / 425 ) processed
# ( 228 / 425 ) processed
# ( 229 / 425 ) processed
# ( 230 / 425 ) processed
# ( 231 / 425 ) processed
# ( 232 / 425 ) processed
# ( 233 / 425 ) processed
# ( 234 / 425 ) processed
# ( 235 / 425 ) processed
# No data available for id= 59c604cebe707846876f1899
# ( 236 / 425 ) processed
# No data available for id= 4c07ca0b221620a19f52f775
# ( 237 / 425 ) processed
# No data available for id= 4de3516bd4c0704405814eda
# ( 238 / 425 ) processed
# ( 239 / 425 ) processed
# No data available for id= 506d65dab0ed6ed677ac4698
# ( 240 / 425 ) processed
# No data available for id= 5ce9474fb3d8e2002c12830f
# ( 241 / 425 ) processed
# ( 242 / 425 ) processed
# ( 243 / 425 ) processed
# No data available for id= 4becfffa9868a59387d75c46
# ( 244 / 425 ) processed
# ( 245 / 425 ) processed
# No data available for id= 4d4ebafa5fb0b1f739ea7d91
# ( 246 / 425 ) processed
# ( 247 / 425 ) processed
# ( 248 / 425 ) processed
# ( 249 / 425 ) processed
# ( 250 / 425 ) processed
# ( 251 / 425 ) processed
# ( 252 / 425 ) processed
# ( 253 / 425 ) processed
# ( 254 / 425 ) processed
# ( 255 / 425 ) processed
# ( 256 / 425 ) processed
# ( 257 / 425 ) processed
# ( 258 / 425 ) processed
# ( 259 / 425 ) processed
# ( 260 / 425 ) processed
# ( 261 / 425 ) processed
# ( 262 / 425 ) processed
# ( 263 / 425 ) processed
# ( 264 / 425 ) processed
# ( 265 / 425 ) processed
# No data available for id= 59fdc36e28374e3a59d73ebe
# ( 266 / 425 ) processed
# ( 267 / 425 ) processed
# ( 268 / 425 ) processed
# ( 269 / 425 ) processed
# ( 270 / 425 ) processed
# No data available for id= 59244587772fbc0d635d6165
# ( 271 / 425 ) processed
# ( 272 / 425 ) processed
# ( 273 / 425 ) processed
# ( 274 / 425 ) processed
# ( 275 / 425 ) processed
# No data available for id= 4f7c0ca1e4b02e009061e44a
# ( 276 / 425 ) processed
# ( 277 / 425 ) processed
# ( 278 / 425 ) processed
# ( 279 / 425 ) processed
# ( 280 / 425 ) processed
# ( 281 / 425 ) processed
# No data available for id= 5bb2498c8ad62e002c573d0a
# ( 282 / 425 ) processed
# ( 283 / 425 ) processed
# ( 284 / 425 ) processed
# ( 285 / 425 ) processed
# ( 286 / 425 ) processed
# ( 287 / 425 ) processed
# ( 288 / 425 ) processed
# ( 289 / 425 ) processed
# ( 290 / 425 ) processed
# No data available for id= 4c61869e69a1c9b6a27136a4
# ( 291 / 425 ) processed
# ( 292 / 425 ) processed
# ( 293 / 425 ) processed
# ( 294 / 425 ) processed
# ( 295 / 425 ) processed
# ( 296 / 425 ) processed
# ( 297 / 425 ) processed
# ( 298 / 425 ) processed
# ( 299 / 425 ) processed
# ( 300 / 425 ) processed
# ( 301 / 425 ) processed
# ( 302 / 425 ) processed
# ( 303 / 425 ) processed
# ( 304 / 425 ) processed
# No data available for id= 4f662ce0e4b0e78c022cc933
# ( 305 / 425 ) processed
# No data available for id= 4d7e3fb7870037043b746d99
# ( 306 / 425 ) processed
# ( 307 / 425 ) processed
# ( 308 / 425 ) processed
# ( 309 / 425 ) processed
# ( 310 / 425 ) processed
# ( 311 / 425 ) processed
# ( 312 / 425 ) processed
# ( 313 / 425 ) processed
# ( 314 / 425 ) processed
# No data available for id= 5a0de4f7a5a3153b49a39654
# ( 315 / 425 ) processed
# ( 316 / 425 ) processed
# ( 317 / 425 ) processed
# ( 318 / 425 ) processed
# ( 319 / 425 ) processed
# No data available for id= 4b7683f7f964a520e04f2ee3
# ( 320 / 425 ) processed
# ( 321 / 425 ) processed
# ( 322 / 425 ) processed
# ( 323 / 425 ) processed
# No data available for id= 4c41a4283735be9a15ad18a4
# ( 324 / 425 ) processed
# ( 325 / 425 ) processed
# ( 326 / 425 ) processed
# ( 327 / 425 ) processed
# No data available for id= 4c445879f0bdd13a4265c9cc
# ( 328 / 425 ) processed
# ( 329 / 425 ) processed
# ( 330 / 425 ) processed
# ( 331 / 425 ) processed
# No data available for id= 51c5a10e498e8a3a63ac74c9
# ( 332 / 425 ) processed
# ( 333 / 425 ) processed
# ( 334 / 425 ) processed
# ( 335 / 425 ) processed
# ( 336 / 425 ) processed
# ( 337 / 425 ) processed
# ( 338 / 425 ) processed
# ( 339 / 425 ) processed
# ( 340 / 425 ) processed
# No data available for id= 4d46bf2fe198721e2f0fd28b
# ( 341 / 425 ) processed
# ( 342 / 425 ) processed
# ( 343 / 425 ) processed
# ( 344 / 425 ) processed
# No data available for id= 51962602498edaccbe7a418f
# ( 345 / 425 ) processed
# ( 346 / 425 ) processed
# ( 347 / 425 ) processed
# ( 348 / 425 ) processed
# ( 349 / 425 ) processed
# ( 350 / 425 ) processed
# ( 351 / 425 ) processed
# ( 352 / 425 ) processed
# ( 353 / 425 ) processed
# ( 354 / 425 ) processed
# ( 355 / 425 ) processed
# ( 356 / 425 ) processed
# ( 357 / 425 ) processed
# ( 358 / 425 ) processed
# ( 359 / 425 ) processed
# ( 360 / 425 ) processed
# ( 361 / 425 ) processed
# No data available for id= 52346d7f11d20770833255af
# ( 362 / 425 ) processed
# ( 363 / 425 ) processed
# ( 364 / 425 ) processed
# ( 365 / 425 ) processed
# ( 366 / 425 ) processed
# ( 367 / 425 ) processed
# ( 368 / 425 ) processed
# ( 369 / 425 ) processed
# ( 370 / 425 ) processed
# ( 371 / 425 ) processed
# ( 372 / 425 ) processed
# ( 373 / 425 ) processed
# ( 374 / 425 ) processed
# No data available for id= 57541797cd10585cbf3a9564
# ( 375 / 425 ) processed
# ( 376 / 425 ) processed
# ( 377 / 425 ) processed
# ( 378 / 425 ) processed
# ( 379 / 425 ) processed
# ( 380 / 425 ) processed
# ( 381 / 425 ) processed
# ( 382 / 425 ) processed
# ( 383 / 425 ) processed
# ( 384 / 425 ) processed
# ( 385 / 425 ) processed
# ( 386 / 425 ) processed
# ( 387 / 425 ) processed
# ( 388 / 425 ) processed
# ( 389 / 425 ) processed
# ( 390 / 425 ) processed
# ( 391 / 425 ) processed
# ( 392 / 425 ) processed
# ( 393 / 425 ) processed
# ( 394 / 425 ) processed
# No data available for id= 527f80dd11d227d63589cd87
# ( 395 / 425 ) processed
# No data available for id= 4b5ef2c3f964a520349f29e3
# ( 396 / 425 ) processed
# ( 397 / 425 ) processed
# ( 398 / 425 ) processed
# ( 399 / 425 ) processed
# No data available for id= 5d094cb0acb00b002c3d1424
# ( 400 / 425 ) processed
# ( 401 / 425 ) processed
# ( 402 / 425 ) processed
# ( 403 / 425 ) processed
# ( 404 / 425 ) processed
# ( 405 / 425 ) processed
# No data available for id= 4f37c169e4b0179e5de2d2f3
# ( 406 / 425 ) processed
# ( 407 / 425 ) processed
# ( 408 / 425 ) processed
# ( 409 / 425 ) processed
# ( 410 / 425 ) processed
# ( 411 / 425 ) processed
# ( 412 / 425 ) processed
# ( 413 / 425 ) processed
# ( 414 / 425 ) processed
# ( 415 / 425 ) processed
# ( 416 / 425 ) processed
# ( 417 / 425 ) processed
# ( 418 / 425 ) processed
# ( 419 / 425 ) processed
# No data available for id= 50e44d37e4b0f6f2e6dc4f10
# ( 420 / 425 ) processed
# No data available for id= 519a4135498e6c0d2100b868
# ( 421 / 425 ) processed
# ( 422 / 425 ) processed
# No data available for id= 4c6685baf7a80f477d2c9e7a
# ( 423 / 425 ) processed
# No data available for id= 4eaea7ff29c2a9bb981f3bd9
# ( 424 / 425 ) processed
# ( 425 / 425 ) processed
# (425, 10)
#                  Borough          Neighborhood                        ID  \
# 0   Kingston upon Thames  Kingston upon Thames  4b6be6b0f964a520f51b2ce3
# 1   Kingston upon Thames  Kingston upon Thames  4b7be82df964a52026732fe3
# 2   Kingston upon Thames  Kingston upon Thames  51af1a17498e9b28860483f5
# 3   Kingston upon Thames  Kingston upon Thames  4ef077bdf9ab3edffbca122e
# 4   Kingston upon Thames  Kingston upon Thames  4b9516a4f964a520948e34e3
# 5   Kingston upon Thames  Kingston upon Thames  54c10f68498e7fe1b568e459
# 6            Westminster         Knightsbridge  5641abb038fa7b01648ae33e
# 7            Westminster         Knightsbridge  5cc1aea3a5a315002cff98f6
# 8            Westminster         Knightsbridge  52d71ac611d2dae852a0be1f
# 9            Westminster         Knightsbridge  5a19c873356b4976e646ed4b
# 10           Westminster         Knightsbridge  4b10f3f0f964a520f37623e3
# 11           Westminster         Knightsbridge  4b3f7d0cf964a520baa725e3
# 12           Westminster         Knightsbridge  5145cc40e4b0dba1b4dda911
# 13           Westminster         Knightsbridge                         0
# 14              Lewisham              Ladywell  4b5a0112f964a52015a728e3
# 15               Lambeth               Lambeth  51e52b0b498e1d7ea31d88c1
# 16               Lambeth               Lambeth  57540ed1498ef7771538048d
# 17               Lambeth               Lambeth  57025a60498e2196f62e9548
# 18               Lambeth               Lambeth  4bc0539e920eb71357ca182c
# 19               Lambeth               Lambeth  5b25626b270ee7002c11755b
#
#     Name Likes  Rating Tips                    Venue  Venue Latitude  \
# 0    NaN    37     7.0   10             Costa Coffee       51.411664
# 1    NaN    94     7.2   14                Starbucks       51.410867
# 2    NaN     4     6.7    1             Costa Coffee       51.411644
# 3    NaN     1     6.5    1          M&S Café Revive       51.410849
# 4    NaN    17     6.4   10               Caffè Nero       51.409690
# 5    NaN     2     5.9    1             Costa Coffee       51.409649
# 6    NaN   492     9.3  120                    Carpo       51.498949
# 7    NaN    11     8.3    5     39 Steps Coffee Haus       51.498929
# 8    NaN  1001     8.5  263          Chapati & Karak       51.498400
# 9    NaN   158     8.8   36           The Coffee Bar       51.499171
# 10   NaN   481     8.2   66                Starbucks       51.500533
# 11   NaN   120     7.6   33               Caffè Nero       51.498947
# 12   NaN     9     6.1    7                Dior Café       51.498800
# 13   NaN     0     0.0    0                        0       51.498748
# 14   NaN    18     8.2    3             Cafe Oscar's       51.456432
# 15   NaN   177     8.4   71             Four Corners       51.500425
# 16   NaN    27     8.3   11          The Travel Cafe       51.499705
# 17   NaN    80     8.5   22  Coleman Coffee Roasters       51.500636
# 18   NaN   227     7.3   28                Starbucks       51.501962
# 19   NaN    20     7.1    5                 Draughts       51.501735
#
#     Venue Longitude
# 0         -0.304736
# 1         -0.301778
# 2         -0.304514
# 3         -0.303804
# 4         -0.304033
# 5         -0.306561
# 6         -0.165498
# 7         -0.165391
# 8         -0.165931
# 9         -0.162803
# 10        -0.162604
# 11        -0.165058
# 12        -0.163534
# 13        -0.164322
# 14        -0.020194
# 15        -0.113660
# 16        -0.114136
# 17        -0.112947
# 18        -0.117661
# 19        -0.115376

# %%
# Remove rows with a Venue that is "0".
cafe_stats_london.drop(cafe_stats_london[cafe_stats_london['ID']=="0"].index,axis=0, inplace=True)

print(cafe_stats_london.shape)
cafe_stats_london.head(20)
# Out:
# (744, 10)
#            Borough Neighborhood                        ID  Name Likes  Rating  \
# 0           Ealing        Acton  517d323fe4b0b4d24c007345   NaN    14     6.4
# 2          Croydon   Addiscombe  533fea17498e1f39b6eab646   NaN    12     7.9
# 3   City of London      Aldgate  4f70a772e4b0f375fc669005   NaN   277     9.0
# 4   City of London      Aldgate  4cb1d779562d224b09ec2188   NaN    32     8.1
# 5   City of London      Aldgate  59f97d45acb00b6e13f7d430   NaN    12     7.7
# 6   City of London      Aldgate  58af36849435a903b9148728   NaN     8     7.4
# 7   City of London      Aldgate  56bd9566498e17276fd1943c   NaN    23     7.8
# 8   City of London      Aldgate  5548bf3e498e5a453a75bb45   NaN    40     7.5
# 9   City of London      Aldgate  56cf0e4c498e3a5a5e7326c3   NaN    18     8.0
# 10  City of London      Aldgate  520e158a11d25f11387631f8   NaN    10     6.9
# 11  City of London      Aldgate  4dbfe04693a0b5a1561e7785   NaN    60     6.6
# 12  City of London      Aldgate  4b03dbaef964a5205f5022e3   NaN    79     6.8
# 13     Westminster      Aldwych  55c34aac498e536d77bc73b0   NaN   193     8.8
# 14     Westminster      Aldwych  4d78eb92b706224b8450308d   NaN   209     8.5
# 15     Westminster      Aldwych  586b9d4e4988da05edce66c1   NaN     9     6.5
# 16     Westminster      Aldwych  4b914a36f964a52060b033e3   NaN    30     6.0
# 18       Islington        Angel  54293665498e82f0e3cc82ea   NaN   177     8.4
# 19       Islington        Angel  4fc9ff8ce4b087d229f75ce4   NaN   492     8.4
# 20       Islington        Angel  5cd6d3c7da5ede002ce4d289   NaN     7     7.8
# 21       Islington        Angel  55a3d418498e2b2b95d79f91   NaN     7     7.6
#
#    Tips                            Venue  Venue Latitude  Venue Longitude
# 0     3                     Costa Coffee       51.506879        -0.269368
# 2     2                    The Tram Stop       51.380188        -0.073378
# 3    89                  The Association       51.513733        -0.079132
# 4    18                          Fazenda       51.516169        -0.077414
# 5     2               Black Sheep Coffee       51.513990        -0.075459
# 6     2                Whitechapel Grind       51.514409        -0.072834
# 7     7                    Nude Espresso       51.516894        -0.075482
# 8    11               Black Sheep Coffee       51.515066        -0.072126
# 9     1  Notes Coffee Roaster & Wine Bar       51.514643        -0.080671
# 10    5                     Peter's Cafe       51.514076        -0.075482
# 11   11                     Costa Coffee       51.514966        -0.072658
# 12   14                        Starbucks       51.511556        -0.075125
# 13   70                        Lundenwic       51.512823        -0.118343
# 14   48           The Fleet Street Press       51.513710        -0.111678
# 15    2                      Soho Coffee       51.513333        -0.113325
# 16   13                      LSE Garrick       51.513405        -0.116588
# 18   43                   Saint Espressō       51.531919        -0.107565
# 19  140          The Coffeeworks Project       51.534254        -0.104684
# 20    3         Scarlett Coffee Roastery       51.533570        -0.104370
# 21    1              Duncan Terrace Cafe       51.531624        -0.104796

# %%
# Save the information so far to a .csv file due to limited calls on FourSquare
cafe_stats_london.to_csv('cafe_stats_london_final.csv')
#cafe_stats_london = pd.read_csv('cafe_stats_london_final.csv')
#cafe_stats_london.head()

# %% [markdown]
# <br> We ended up with 744 cafés in total, which a good number to progress with our analysis. <br>
# <br>
# Now we will focus on the neighborhoods and their cafés, and see which ones will meet our requirements to be considered as a good location and appreciated by potential customers. <br>
# We will first look at check the overall rating of cafés per neighborhood and borough, which will already allow us to have a first idea. We will then reduce our list by focusing only on neighborhoods with high rating. <br><br>

# %%
# converting the Likes and Tips to float
cafe_stats_london['Likes']=cafe_stats_london['Likes'].astype('float64')
cafe_stats_london['Tips']=cafe_stats_london['Tips'].astype('float64')
cafe_stats_london.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 744 entries, 0 to 424
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Borough          744 non-null    object
#  1   Neighborhood     744 non-null    object
#  2   ID               744 non-null    object
#  3   Name             0 non-null      float64
#  4   Likes            744 non-null    float64
#  5   Rating           744 non-null    float64
#  6   Tips             744 non-null    float64
#  7   Venue            744 non-null    object
#  8   Venue Latitude   744 non-null    float64
#  9   Venue Longitude  744 non-null    float64
# dtypes: float64(6), object(4)
# memory usage: 63.9+ KB

# %%
# get the average rating of cafés in each neighborhood
cafe_neighborhood=cafe_stats_london.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
cafe_neighborhood.columns=['Neighborhood','Average Rating']
cafe_neighborhood.sort_values(['Average Rating'],ascending=False).head(20)
# Out:
#      Neighborhood  Average Rating
# 142     Limehouse        9.100000
# 25        Brixton        9.100000
# 124      Homerton        9.000000
# 67       Deptford        8.900000
# 154    Nag's Head        8.850000
# 234    West Green        8.700000
# 22     Bowes Park        8.700000
# 14   Belsize Park        8.600000
# 63        Dalston        8.600000
# 170   Pentonville        8.600000
# 226      Vauxhall        8.600000
# 44        Chelsea        8.600000
# 10      Battersea        8.500000
# 46      Chinatown        8.500000
# 133  King's Cross        8.500000
# 199    St James's        8.500000
# 102       Hackney        8.466667
# 149       Mayfair        8.450000
# 93   Fortis Green        8.400000
# 185    Shoreditch        8.388889

# %%
# get the average rating of cafés in each borough
cafe_borough=cafe_stats_london.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
cafe_borough.columns=['Borough','Average Rating']
cafe_borough.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#                        Borough  Average Rating
# 6         Camden and Islington        8.500000
# 22  Islington & City of London        8.333333
# 23      Kensington and Chelsea        7.890909
# 34               Tower Hamlets        7.879310
# 13                     Hackney        7.800000
# 7               City of London        7.743750
# 37                 Westminster        7.555385
# 21                   Islington        7.517391
# 5                       Camden        7.455385
# 36                  Wandsworth        7.341379

# %% [markdown]
# <br>We would like to open our café in a neighborhood where cafés have a good rating - for this project, we decided to focus on the neighborhood with rating equal to or greater than 8.<br>
# We will visually map the neighborhoods with an average rating equal to or greater than 8, which will give us a better idea on our current results.<br><br>

# %%
cafe_neighborhood=cafe_neighborhood[cafe_neighborhood['Average Rating']>=8.0]
cafe_neighborhood=pd.merge(cafe_neighborhood,london_df, on='Neighborhood')
cafe_neighborhood=cafe_neighborhood[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]

# sorting the neighborhoods by average rating, in a descending way.
cafe_neighborhood.sort_values(by='Average Rating', ascending=False, inplace=True)

# add the column number of venues per neighborhood
c_df = london_cafe_df[["Neighborhood", "Venue"]].copy()
count_df = c_df.groupby('Neighborhood')['Venue'].count()
london_cafe_df = london_cafe_df.merge(count_df, on='Neighborhood', how='left')

print(cafe_neighborhood.shape)
cafe_neighborhood
# Out:
# (43, 5)
#                        Borough      Neighborhood   Latitude  Longitude  \
# 5                      Lambeth           Brixton  51.456804  -0.116796
# 28               Tower Hamlets         Limehouse  51.513307  -0.035149
# 23                     Hackney          Homerton  51.547079  -0.043121
# 16                    Lewisham          Deptford  51.475845  -0.021516
# 31                   Islington        Nag's Head  51.512979  -0.123620
# 42                    Haringey        West Green  51.586806  -0.089849
# 4                     Haringey        Bowes Park  51.607186  -0.120485
# 33                   Islington       Pentonville  51.531858  -0.108423
# 15                     Hackney           Dalston  51.543402  -0.067229
# 11      Kensington and Chelsea           Chelsea  51.487542  -0.168220
# 40                     Lambeth          Vauxhall  51.487483  -0.122930
# 2                       Camden      Belsize Park  51.547393  -0.168301
# 12                 Westminster         Chinatown  51.511680  -0.130496
# 37                 Westminster        St James's  51.507908  -0.136573
# 24        Camden and Islington      King's Cross  51.532395  -0.123022
# 1                   Wandsworth         Battersea  51.470793  -0.172214
# 22                     Hackney           Hackney  51.543240  -0.049362
# 30                 Westminster           Mayfair  51.511087  -0.147058
# 20                    Haringey      Fortis Green  51.590997  -0.153421
# 34                     Hackney        Shoreditch  51.526669  -0.079893
# 36               Tower Hamlets      Spitalfields  51.519527  -0.075170
# 19                      Camden         Fitzrovia  51.518764  -0.141002
# 18  Islington & City of London        Farringdon  51.520124  -0.104793
# 21      Hammersmith and Fulham            Fulham  51.474422  -0.206077
# 32      Kensington and Chelsea  North Kensington  51.519665  -0.210696
# 3                Tower Hamlets     Bethnal Green  51.530346  -0.056163
# 14                     Croydon           Croydon  51.371305  -0.101957
# 8         Richmond upon Thames         Castelnau  51.487429  -0.231228
# 26                    Lewisham          Ladywell  51.456026  -0.019192
# 35                 Westminster              Soho  51.513163  -0.131175
# 38                    Haringey   Tottenham Green  51.587754  -0.071476
# 13                 Westminster     Covent Garden  51.512874  -0.122544
# 41               Tower Hamlets           Wapping  51.505436  -0.058729
# 0               City of London          Barbican  51.520150  -0.098683
# 25                 Westminster     Knightsbridge  51.500844  -0.166965
# 39                    Havering  Upminster Bridge  51.558266   0.234769
# 27              Waltham Forest       Leytonstone  51.571078   0.006424
# 10                   Greenwich          Charlton  51.482605   0.036536
# 6                Tower Hamlets   Cambridge Heath  51.531954  -0.057422
# 17      Kensington and Chelsea       Earls Court  51.491612  -0.193903
# 7                    Islington         Canonbury  51.543036  -0.095401
# 29                 Westminster     Little Venice  51.521195  -0.182404
# 9                  Westminster     Charing Cross  51.507497  -0.123689
#
#     Average Rating
# 5         9.100000
# 28        9.100000
# 23        9.000000
# 16        8.900000
# 31        8.850000
# 42        8.700000
# 4         8.700000
# 33        8.600000
# 15        8.600000
# 11        8.600000
# 40        8.600000
# 2         8.600000
# 12        8.500000
# 37        8.500000
# 24        8.500000
# 1         8.500000
# 22        8.466667
# 30        8.450000
# 20        8.400000
# 34        8.388889
# 36        8.383333
# 19        8.357143
# 18        8.333333
# 21        8.300000
# 32        8.300000
# 3         8.266667
# 14        8.250000
# 8         8.250000
# 26        8.200000
# 35        8.200000
# 38        8.200000
# 13        8.180000
# 41        8.150000
# 0         8.133333
# 25        8.114286
# 39        8.100000
# 27        8.100000
# 10        8.100000
# 6         8.100000
# 17        8.000000
# 7         8.000000
# 29        8.000000
# 9         8.000000

# %% [markdown]
# <br> We got 43 potential good neighborhoods. Let's visualize them in London map. <br>

# %%
import folium
import seaborn as sns
from geopy.geocoders import Nominatim 

def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# create London map and display it
london_map = folium.Map(location=geo_location('London'), zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the neighborhoods
for lat, lng, in cafe_neighborhood[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='black',
            fill=True,
            fill_color='yellow',
            fill_opacity=0.6
        )
    )
    
cafe_neighborhood['Label']=cafe_neighborhood['Neighborhood']+', '+cafe_neighborhood['Borough']+'('+cafe_neighborhood['Average Rating'].map(str)+')'

# add pop-up text to each marker on the map
for lat, lng, label in cafe_neighborhood[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(london_map)        

    # add incidents to map
london_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <br> To reduce further our list of potential good neighborhoods, we will now consider that number of cafés per neighborhood. <br><br>
# A good location will be a place known for its good coffee (high rating). To make sure that this rating is relevant, we will expect that the neighborhood should have at least 3 or more cafés already. <br>
# Let's drop the ones with 1 or 2 coffee shops.

# %%
# add the column number of venues per neighborhood
total = london_cafe_df.groupby(['Neighborhood'])['Venue_x'].count().reset_index(name="Number of Venue")

cafe_neighborhood = cafe_neighborhood.merge(total, on='Neighborhood', how='left')

print(cafe_neighborhood.shape)
cafe_neighborhood
# Out:
# (43, 7)
#                        Borough      Neighborhood   Latitude  Longitude  \
# 0                      Lambeth           Brixton  51.456804  -0.116796
# 1                Tower Hamlets         Limehouse  51.513307  -0.035149
# 2                      Hackney          Homerton  51.547079  -0.043121
# 3                     Lewisham          Deptford  51.475845  -0.021516
# 4                    Islington        Nag's Head  51.512979  -0.123620
# 5                     Haringey        West Green  51.586806  -0.089849
# 6                     Haringey        Bowes Park  51.607186  -0.120485
# 7                    Islington       Pentonville  51.531858  -0.108423
# 8                      Hackney           Dalston  51.543402  -0.067229
# 9       Kensington and Chelsea           Chelsea  51.487542  -0.168220
# 10                     Lambeth          Vauxhall  51.487483  -0.122930
# 11                      Camden      Belsize Park  51.547393  -0.168301
# 12                 Westminster         Chinatown  51.511680  -0.130496
# 13                 Westminster        St James's  51.507908  -0.136573
# 14        Camden and Islington      King's Cross  51.532395  -0.123022
# 15                  Wandsworth         Battersea  51.470793  -0.172214
# 16                     Hackney           Hackney  51.543240  -0.049362
# 17                 Westminster           Mayfair  51.511087  -0.147058
# 18                    Haringey      Fortis Green  51.590997  -0.153421
# 19                     Hackney        Shoreditch  51.526669  -0.079893
# 20               Tower Hamlets      Spitalfields  51.519527  -0.075170
# 21                      Camden         Fitzrovia  51.518764  -0.141002
# 22  Islington & City of London        Farringdon  51.520124  -0.104793
# 23      Hammersmith and Fulham            Fulham  51.474422  -0.206077
# 24      Kensington and Chelsea  North Kensington  51.519665  -0.210696
# 25               Tower Hamlets     Bethnal Green  51.530346  -0.056163
# 26                     Croydon           Croydon  51.371305  -0.101957
# 27        Richmond upon Thames         Castelnau  51.487429  -0.231228
# 28                    Lewisham          Ladywell  51.456026  -0.019192
# 29                 Westminster              Soho  51.513163  -0.131175
# 30                    Haringey   Tottenham Green  51.587754  -0.071476
# 31                 Westminster     Covent Garden  51.512874  -0.122544
# 32               Tower Hamlets           Wapping  51.505436  -0.058729
# 33              City of London          Barbican  51.520150  -0.098683
# 34                 Westminster     Knightsbridge  51.500844  -0.166965
# 35                    Havering  Upminster Bridge  51.558266   0.234769
# 36              Waltham Forest       Leytonstone  51.571078   0.006424
# 37                   Greenwich          Charlton  51.482605   0.036536
# 38               Tower Hamlets   Cambridge Heath  51.531954  -0.057422
# 39      Kensington and Chelsea       Earls Court  51.491612  -0.193903
# 40                   Islington         Canonbury  51.543036  -0.095401
# 41                 Westminster     Little Venice  51.521195  -0.182404
# 42                 Westminster     Charing Cross  51.507497  -0.123689
#
#     Average Rating                                              Label  \
# 0         9.100000                              Brixton, Lambeth(9.1)
# 1         9.100000                      Limehouse, Tower Hamlets(9.1)
# 2         9.000000                             Homerton, Hackney(9.0)
# 3         8.900000                            Deptford, Lewisham(8.9)
# 4         8.850000                        Nag's Head, Islington(8.85)
# 5         8.700000                          West Green, Haringey(8.7)
# 6         8.700000                          Bowes Park, Haringey(8.7)
# 7         8.600000                        Pentonville, Islington(8.6)
# 8         8.600000                              Dalston, Hackney(8.6)
# 9         8.600000               Chelsea, Kensington and Chelsea(8.6)
# 10        8.600000                             Vauxhall, Lambeth(8.6)
# 11        8.600000                          Belsize Park, Camden(8.6)
# 12        8.500000                        Chinatown, Westminster(8.5)
# 13        8.500000                       St James's, Westminster(8.5)
# 14        8.500000            King's Cross, Camden and Islington(8.5)
# 15        8.500000                         Battersea, Wandsworth(8.5)
# 16        8.466667                Hackney, Hackney(8.466666666666667)
# 17        8.450000                         Mayfair, Westminster(8.45)
# 18        8.400000                        Fortis Green, Haringey(8.4)
# 19        8.388889              Shoreditch, Hackney(8.38888888888889)
# 20        8.383333     Spitalfields, Tower Hamlets(8.383333333333333)
# 21        8.357143               Fitzrovia, Camden(8.357142857142858)
# 22        8.333333  Farringdon, Islington & City of London(8.33333...
# 23        8.300000                Fulham, Hammersmith and Fulham(8.3)
# 24        8.300000  North Kensington, Kensington and Chelsea(8.299...
# 25        8.266667    Bethnal Green, Tower Hamlets(8.266666666666667)
# 26        8.250000                             Croydon, Croydon(8.25)
# 27        8.250000              Castelnau, Richmond upon Thames(8.25)
# 28        8.200000                            Ladywell, Lewisham(8.2)
# 29        8.200000                             Soho, Westminster(8.2)
# 30        8.200000                     Tottenham Green, Haringey(8.2)
# 31        8.180000                   Covent Garden, Westminster(8.18)
# 32        8.150000                       Wapping, Tower Hamlets(8.15)
# 33        8.133333        Barbican, City of London(8.133333333333335)
# 34        8.114286      Knightsbridge, Westminster(8.114285714285716)
# 35        8.100000                    Upminster Bridge, Havering(8.1)
# 36        8.100000                   Leytonstone, Waltham Forest(8.1)
# 37        8.100000                           Charlton, Greenwich(8.1)
# 38        8.100000                Cambridge Heath, Tower Hamlets(8.1)
# 39        8.000000           Earls Court, Kensington and Chelsea(8.0)
# 40        8.000000                          Canonbury, Islington(8.0)
# 41        8.000000                    Little Venice, Westminster(8.0)
# 42        8.000000                    Charing Cross, Westminster(8.0)
#
#     Number of Venue
# 0                 1
# 1                 2
# 2                 1
# 3                 1
# 4                 2
# 5                 1
# 6                 2
# 7                 2
# 8                 1
# 9                 2
# 10                2
# 11                2
# 12                2
# 13                1
# 14                1
# 15                1
# 16                4
# 17                2
# 18                1
# 19               11
# 20                6
# 21               14
# 22                3
# 23                3
# 24                3
# 25                6
# 26                2
# 27                2
# 28                1
# 29                1
# 30                1
# 31                5
# 32                2
# 33                3
# 34                8
# 35                1
# 36                1
# 37                1
# 38                1
# 39                4
# 40                3
# 41                4
# 42                1

# %%
#let's consider only the neighborhood with at least cafés - so data can be more accurate
cafe_neighborhood2 = cafe_neighborhood.loc[(cafe_neighborhood['Number of Venue'] >2)]
cafe_neighborhood2
# Out:
#                        Borough      Neighborhood   Latitude  Longitude  \
# 16                     Hackney           Hackney  51.543240  -0.049362
# 19                     Hackney        Shoreditch  51.526669  -0.079893
# 20               Tower Hamlets      Spitalfields  51.519527  -0.075170
# 21                      Camden         Fitzrovia  51.518764  -0.141002
# 22  Islington & City of London        Farringdon  51.520124  -0.104793
# 23      Hammersmith and Fulham            Fulham  51.474422  -0.206077
# 24      Kensington and Chelsea  North Kensington  51.519665  -0.210696
# 25               Tower Hamlets     Bethnal Green  51.530346  -0.056163
# 31                 Westminster     Covent Garden  51.512874  -0.122544
# 33              City of London          Barbican  51.520150  -0.098683
# 34                 Westminster     Knightsbridge  51.500844  -0.166965
# 39      Kensington and Chelsea       Earls Court  51.491612  -0.193903
# 40                   Islington         Canonbury  51.543036  -0.095401
# 41                 Westminster     Little Venice  51.521195  -0.182404
#
#     Average Rating                                              Label  \
# 16        8.466667                Hackney, Hackney(8.466666666666667)
# 19        8.388889              Shoreditch, Hackney(8.38888888888889)
# 20        8.383333     Spitalfields, Tower Hamlets(8.383333333333333)
# 21        8.357143               Fitzrovia, Camden(8.357142857142858)
# 22        8.333333  Farringdon, Islington & City of London(8.33333...
# 23        8.300000                Fulham, Hammersmith and Fulham(8.3)
# 24        8.300000  North Kensington, Kensington and Chelsea(8.299...
# 25        8.266667    Bethnal Green, Tower Hamlets(8.266666666666667)
# 31        8.180000                   Covent Garden, Westminster(8.18)
# 33        8.133333        Barbican, City of London(8.133333333333335)
# 34        8.114286      Knightsbridge, Westminster(8.114285714285716)
# 39        8.000000           Earls Court, Kensington and Chelsea(8.0)
# 40        8.000000                          Canonbury, Islington(8.0)
# 41        8.000000                    Little Venice, Westminster(8.0)
#
#     Number of Venue
# 16                4
# 19               11
# 20                6
# 21               14
# 22                3
# 23                3
# 24                3
# 25                6
# 31                5
# 33                3
# 34                8
# 39                4
# 40                3
# 41                4

# %%
for lat, lng, in cafe_neighborhood2[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='black',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        )
    )
    
cafe_neighborhood2['Label']=cafe_neighborhood2['Neighborhood']+', '+cafe_neighborhood2['Borough']+'('+cafe_neighborhood2['Average Rating'].map(str)+')'

# add pop-up text to each marker on the map
for lat, lng, label in cafe_neighborhood2[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(london_map)        

    # add incidents to map
london_map.add_child(incidents)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <br>
# This looks so much better. Let's analyze these results and propose the best three locations to open a new café in London.<br><br><br>

# %% [markdown]
# ### <b>Results and discussion section</b><br>
# <br>
# Our analysis shows that although there is a great number of cafés in London (around 800 in 500 neighborhoods), there are few locations with acceptable density, close to city center and very appreciated for their coffee cultures. <br><br>
# The highest concentration of cafés was detected in Camden and Westminster, which are touristic areas and neighborhoods known by a high density of people. We tried to avoid these neighborhoods, since the competition is already strong there and they probably have faithful customers not willing to change their habits. <br>
# We still were looking at popular areas that offer a combination of popularity among tourists/locals, closeness to city center and a strong socio-economic dynamics (close to business areas like Canary Wharf).<br>
# After that, we had to start looking at the neighborhoods with a reasonable (fairly low) number of open cafés, but on the other hand eliminated the ones with only 1 or 2 cafés - considered as not good locations, since not known for their strong coffee culture. <br><br>
#
# Result of all this is 14 neighborhoods representing potential locations. This, of course, does not clearly solve our problem, since we still need to reduce that number and identify the best three locations for a new café. <br><br>
# Recommended locations should meet past conditions, but also be more selective. First, we should only focus on neighborhoods with less than 8 open cafés already, and Second, a good density of people - and that's where we will use our dataframe detailing the number of population by borough. <br><br>
# Based on that, the best three neighborhoods, with small competition, close to city center, known by a good coffee culture and have a good population density are: <br>
# 1- Hackney  <br>
# 2- Spitalfields<br>
# 3- Farringdon<br>
# <br>
# <br>

# %% [markdown]
# ### <b>Conclusion section</b><br>
# <br>
# The purpose of this project was to identify London neighborhoods close to center with low number of cafés, in order to aid entrepreneurs in narrowing down the search for optimal locations for their new coffee shop. By calculating the café density and average rating per neighborhood/borough using Foursquare API/data, we first identified around 50 neighborhoods that can be considered for further analysis. Then we started looking at the competition and the population (which can be translated to potential future customers).<br><br>
# To have good chances of success, it is recommended to open a new café in Hackney neighborhood. There are only 4 other cafés already open, with an average rating of 8.46 on a scale from 1.0 to 10.00 (considered very high comparing to other areas) and with a decent population (around 300000 people).<br>
# To not limit the choice to one neighborhood, we also recommended Spitalfields and Farringdon as the 2nd and 3rd best locations to open a café. This will offer a better flexibility for the entrepreneurs knowing that it's not easy to find a shop to rent or buy in city center. <br><br>
# As a final note, these results can be further developed by doing similar analysis by streets (focusing on the three proposed areas) and also consider the real estate situation (the availability of a shop, how much renting will cost, etc...) which will increase the chance to build a sustainable and lucrative coffee business. This will require a different datasets.
